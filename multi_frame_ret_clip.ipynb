# %% [markdown]
# Video retrieval by embedding multiple frames using CLIP where multiple frame vectors were combined to a single vector using mean pooling.

# %%
import os
import csv
from towhee import ops, pipe, register
from towhee.operator import PyOperator
from towhee import DataCollection
from tqdm import tqdm
import pandas as pd
import json
import numpy as np
from helpers import milvus_utils
from helpers.extract_frames import extract_frame, extract_n_frames
from helpers.eval_utils import twohee_data_col_to_df, get_all_eval_scores

# %%
# CONSTANTS

# Files
MSRVTT_SAMPLES = "./MSRVTT_1K.csv"
MSRVTT_SAMPLES_WITH_4_FRAMES = "./MSRVTT_1K_4_frames.csv"
MSRVTT_SAMPLES_WITH_8_FRAMES = "./MSRVTT_1K_8_frames.csv"
# file created using raw FIRE judgements, see clean_fire_judgements.ipynb
FIRE_BENCHMARK_Q_JUDGEMENTS = "./fire_benchmark_q_judgements.csv" 

# Database Collections
FRAME_4_RET_COLLECTION = "multi_frame_ret_4"
FRAME_8_RET_COLLECTION = "multi_frame_ret_8"

MULTI_FRAMES_4_DIR = "./frames_data/1k_multi_frames_4"
MULTI_FRAMES_8_DIR = "./frames_data/1k_multi_frames_8"

# %%
raw_samples_df = pd.read_csv(MSRVTT_SAMPLES)
raw_samples_df[['video_id', 'video_path', 'sentence']].head()
# Out:
#     video_id                        video_path  \
# 0  video7579  ./test_1k_compress/video7579.mp4
# 1  video7725  ./test_1k_compress/video7725.mp4
# 2  video9258  ./test_1k_compress/video9258.mp4
# 3  video7365  ./test_1k_compress/video7365.mp4
# 4  video8068  ./test_1k_compress/video8068.mp4
#
#                                             sentence
# 0  a girl wearing red top and black trouser is pu...
# 1  young people sit around the edges of a room cl...
# 2                          a person is using a phone
# 3          cartoon people are eating at a restaurant
# 4                a woman on a couch talks to a a man

# %% [markdown]
# Before we embed video frames, we need to extract multiple frames (4 and 8 for each of the 2 experiments) from each of the 1000 videos.

# %%
def create_multi_frame_dataset(raw_samples_df, num_frames, directory_name):
    raw_video_samples = raw_samples_df.copy()
    for row in tqdm(raw_video_samples.iterrows(), total=len(raw_video_samples)):
        video_path = row[1]['video_path']
        image_name = os.path.basename(video_path).split('.')[0]
        all_frame_paths = extract_n_frames(video_path, directory_name, num_frames)
        for num_f in range(num_frames):
            raw_video_samples.at[row[0], f'frame_path_{num_f+1}'] = all_frame_paths[num_f]
        raw_video_samples.at[row[0], 'frame_id'] = image_name
    
    return raw_video_samples

# %%
four_multi_frame_samples_df = create_multi_frame_dataset(raw_samples_df, 4, MULTI_FRAMES_4_DIR)
eight_multi_frame_samples_df = create_multi_frame_dataset(raw_samples_df, 8, MULTI_FRAMES_8_DIR)
# Out:
# 100%|██████████| 1000/1000 [00:29<00:00, 33.55it/s]
# 100%|██████████| 1000/1000 [00:42<00:00, 23.67it/s]

# %%
four_multi_frame_samples_df.head()
# Out:
#    Unnamed: 0     key  vid_key   video_id  \
# 0         521  ret521  msr7579  video7579
# 1         737  ret737  msr7725  video7725
# 2         740  ret740  msr9258  video9258
# 3         660  ret660  msr7365  video7365
# 4         411  ret411  msr8068  video8068
#
#                                             sentence  \
# 0  a girl wearing red top and black trouser is pu...
# 1  young people sit around the edges of a room cl...
# 2                          a person is using a phone
# 3          cartoon people are eating at a restaurant
# 4                a woman on a couch talks to a a man
#
#                          video_path  \
# 0  ./test_1k_compress/video7579.mp4
# 1  ./test_1k_compress/video7725.mp4
# 2  ./test_1k_compress/video9258.mp4
# 3  ./test_1k_compress/video7365.mp4
# 4  ./test_1k_compress/video8068.mp4
#
#                                         frame_path_1  \
# 0  ./frames_data/1k_multi_frames_4/video7579_fram...
# 1  ./frames_data/1k_multi_frames_4/video7725_fram...
# 2  ./frames_data/1k_multi_frames_4/video9258_fram...
# 3  ./frames_data/1k_multi_frames_4/video7365_fram...
# 4  ./frames_data/1k_multi_frames_4/video8068_fram...
#
#                                         frame_path_2  \
# 0  ./frames_data/1k_multi_frames_4/video7579_fram...
# 1  ./frames_data/1k_multi_frames_4/video7725_fram...
# 2  ./frames_data/1k_multi_frames_4/video9258_fram...
# 3  ./frames_data/1k_multi_frames_4/video7365_fram...
# 4  ./frames_data/1k_multi_frames_4/video8068_fram...
#
#                                         frame_path_3  \
# 0  ./frames_data/1k_multi_frames_4/video7579_fram...
# 1  ./frames_data/1k_multi_frames_4/video7725_fram...
# 2  ./frames_data/1k_multi_frames_4/video9258_fram...
# 3  ./frames_data/1k_multi_frames_4/video7365_fram...
# 4  ./frames_data/1k_multi_frames_4/video8068_fram...
#
#                                         frame_path_4  \
# 0  ./frames_data/1k_multi_frames_4/video7579_fram...
# 1  ./frames_data/1k_multi_frames_4/video7725_fram...
# 2  ./frames_data/1k_multi_frames_4/video9258_fram...
# 3  ./frames_data/1k_multi_frames_4/video7365_fram...
# 4  ./frames_data/1k_multi_frames_4/video8068_fram...
#
#                                         frame_path_5  \
# 0  ./frames_data/1k_multi_frames_8/video7579_fram...
# 1  ./frames_data/1k_multi_frames_8/video7725_fram...
# 2  ./frames_data/1k_multi_frames_8/video9258_fram...
# 3  ./frames_data/1k_multi_frames_8/video7365_fram...
# 4  ./frames_data/1k_multi_frames_8/video8068_fram...
#
#                                         frame_path_6  \
# 0  ./frames_data/1k_multi_frames_8/video7579_fram...
# 1  ./frames_data/1k_multi_frames_8/video7725_fram...
# 2  ./frames_data/1k_multi_frames_8/video9258_fram...
# 3  ./frames_data/1k_multi_frames_8/video7365_fram...
# 4  ./frames_data/1k_multi_frames_8/video8068_fram...
#
#                                         frame_path_7  \
# 0  ./frames_data/1k_multi_frames_8/video7579_fram...
# 1  ./frames_data/1k_multi_frames_8/video7725_fram...
# 2  ./frames_data/1k_multi_frames_8/video9258_fram...
# 3  ./frames_data/1k_multi_frames_8/video7365_fram...
# 4  ./frames_data/1k_multi_frames_8/video8068_fram...
#
#                                         frame_path_8   frame_id
# 0  ./frames_data/1k_multi_frames_8/video7579_fram...  video7579
# 1  ./frames_data/1k_multi_frames_8/video7725_fram...  video7725
# 2  ./frames_data/1k_multi_frames_8/video9258_fram...  video9258
# 3  ./frames_data/1k_multi_frames_8/video7365_fram...  video7365
# 4  ./frames_data/1k_multi_frames_8/video8068_fram...  video8068

# %%
eight_multi_frame_samples_df.head()
# Out:
#    Unnamed: 0     key  vid_key   video_id  \
# 0         521  ret521  msr7579  video7579
# 1         737  ret737  msr7725  video7725
# 2         740  ret740  msr9258  video9258
# 3         660  ret660  msr7365  video7365
# 4         411  ret411  msr8068  video8068
#
#                                             sentence  \
# 0  a girl wearing red top and black trouser is pu...
# 1  young people sit around the edges of a room cl...
# 2                          a person is using a phone
# 3          cartoon people are eating at a restaurant
# 4                a woman on a couch talks to a a man
#
#                          video_path  \
# 0  ./test_1k_compress/video7579.mp4
# 1  ./test_1k_compress/video7725.mp4
# 2  ./test_1k_compress/video9258.mp4
# 3  ./test_1k_compress/video7365.mp4
# 4  ./test_1k_compress/video8068.mp4
#
#                                         frame_path_1  \
# 0  ./frames_data/1k_multi_frames_8/video7579_fram...
# 1  ./frames_data/1k_multi_frames_8/video7725_fram...
# 2  ./frames_data/1k_multi_frames_8/video9258_fram...
# 3  ./frames_data/1k_multi_frames_8/video7365_fram...
# 4  ./frames_data/1k_multi_frames_8/video8068_fram...
#
#                                         frame_path_2  \
# 0  ./frames_data/1k_multi_frames_8/video7579_fram...
# 1  ./frames_data/1k_multi_frames_8/video7725_fram...
# 2  ./frames_data/1k_multi_frames_8/video9258_fram...
# 3  ./frames_data/1k_multi_frames_8/video7365_fram...
# 4  ./frames_data/1k_multi_frames_8/video8068_fram...
#
#                                         frame_path_3  \
# 0  ./frames_data/1k_multi_frames_8/video7579_fram...
# 1  ./frames_data/1k_multi_frames_8/video7725_fram...
# 2  ./frames_data/1k_multi_frames_8/video9258_fram...
# 3  ./frames_data/1k_multi_frames_8/video7365_fram...
# 4  ./frames_data/1k_multi_frames_8/video8068_fram...
#
#                                         frame_path_4  \
# 0  ./frames_data/1k_multi_frames_8/video7579_fram...
# 1  ./frames_data/1k_multi_frames_8/video7725_fram...
# 2  ./frames_data/1k_multi_frames_8/video9258_fram...
# 3  ./frames_data/1k_multi_frames_8/video7365_fram...
# 4  ./frames_data/1k_multi_frames_8/video8068_fram...
#
#                                         frame_path_5  \
# 0  ./frames_data/1k_multi_frames_8/video7579_fram...
# 1  ./frames_data/1k_multi_frames_8/video7725_fram...
# 2  ./frames_data/1k_multi_frames_8/video9258_fram...
# 3  ./frames_data/1k_multi_frames_8/video7365_fram...
# 4  ./frames_data/1k_multi_frames_8/video8068_fram...
#
#                                         frame_path_6  \
# 0  ./frames_data/1k_multi_frames_8/video7579_fram...
# 1  ./frames_data/1k_multi_frames_8/video7725_fram...
# 2  ./frames_data/1k_multi_frames_8/video9258_fram...
# 3  ./frames_data/1k_multi_frames_8/video7365_fram...
# 4  ./frames_data/1k_multi_frames_8/video8068_fram...
#
#                                         frame_path_7  \
# 0  ./frames_data/1k_multi_frames_8/video7579_fram...
# 1  ./frames_data/1k_multi_frames_8/video7725_fram...
# 2  ./frames_data/1k_multi_frames_8/video9258_fram...
# 3  ./frames_data/1k_multi_frames_8/video7365_fram...
# 4  ./frames_data/1k_multi_frames_8/video8068_fram...
#
#                                         frame_path_8   frame_id
# 0  ./frames_data/1k_multi_frames_8/video7579_fram...  video7579
# 1  ./frames_data/1k_multi_frames_8/video7725_fram...  video7725
# 2  ./frames_data/1k_multi_frames_8/video9258_fram...  video9258
# 3  ./frames_data/1k_multi_frames_8/video7365_fram...  video7365
# 4  ./frames_data/1k_multi_frames_8/video8068_fram...  video8068

# %%
# We write the transformed samples data to a CSV file so it can be loaded into the load pipeline
def frame_path_cols(num_frames):
    cols = []
    for i in range(num_frames):
        cols.append(f'frame_path_{i+1}')
    return cols

columns_4_multi = frame_path_cols(4) + ['video_id', 'frame_id', 'sentence']
columns_8_multi = frame_path_cols(8) + ['video_id', 'frame_id', 'sentence']

four_multi_frame_samples_df[columns_4_multi].to_csv(MSRVTT_SAMPLES_WITH_4_FRAMES, index=False)
eight_multi_frame_samples_df[columns_8_multi].to_csv(MSRVTT_SAMPLES_WITH_8_FRAMES, index=False)

# %%
# Create the collection in Milvus to store image embeddings
milvus_utils.create_milvus_collection(FRAME_4_RET_COLLECTION, 512)
milvus_utils.create_milvus_collection(FRAME_8_RET_COLLECTION, 512)
# Out:
# <Collection>:
# -------------
# <name>: multi_frame_ret_8
# <description>: video retrieval
# <schema>: {'auto_id': False, 'description': 'video retrieval', 'fields': [{'name': 'id', 'description': '', 'type': <DataType.INT64: 5>, 'is_primary': True, 'auto_id': False}, {'name': 'embedding', 'description': '', 'type': <DataType.FLOAT_VECTOR: 101>, 'params': {'dim': 512}}]}

# %%
def get_frame_loader_csv(num_frames):
    f_path_col_names = [f"frame_path_{i+1}" for i in range(num_frames)]
    
    def read_frame_loader_csv(csv_path, encoding='utf-8-sig'):
        with open(csv_path, 'r', encoding=encoding) as f:
            data = csv.DictReader(f)
            for line in data:
                raw_id = line['frame_id']
                cleaned_id = raw_id[len('video'):]
                
                yield (int(cleaned_id),) + tuple(line[f] for f in f_path_col_names)
                # This yields cleaned_id, frame_path_1, frame_path_2, ... frame_path_num_frames
    
    return read_frame_loader_csv

# %%
I = get_frame_loader_csv(8)(MSRVTT_SAMPLES_WITH_8_FRAMES)
next(I)
# Out:
# (7579,
#  './frames_data/1k_multi_frames_8/video7579_frame_001_of_008.jpg',
#  './frames_data/1k_multi_frames_8/video7579_frame_002_of_008.jpg',
#  './frames_data/1k_multi_frames_8/video7579_frame_003_of_008.jpg',
#  './frames_data/1k_multi_frames_8/video7579_frame_004_of_008.jpg',
#  './frames_data/1k_multi_frames_8/video7579_frame_005_of_008.jpg',
#  './frames_data/1k_multi_frames_8/video7579_frame_006_of_008.jpg',
#  './frames_data/1k_multi_frames_8/video7579_frame_007_of_008.jpg',
#  './frames_data/1k_multi_frames_8/video7579_frame_008_of_008.jpg')

# %%
# Create loader pipelines for 4 and 8 multi frames
four_frame_csv_loader = get_frame_loader_csv(4)
multi_4_frame_loader_pipeline = (
    pipe.input('csv_file')
    .flat_map('csv_file', ('frame_id', 'f_path_1', 'f_path_2', 'f_path_3', 'f_path_4',), four_frame_csv_loader)
    .map('f_path_1', 'img1', ops.image_decode.cv2('rgb'))
    .map('f_path_2', 'img2', ops.image_decode.cv2('rgb'))
    .map('f_path_3', 'img3', ops.image_decode.cv2('rgb'))
    .map('f_path_4', 'img4', ops.image_decode.cv2('rgb'))
    .map('img1', 'vec1', ops.image_text_embedding.clip(model_name='clip_vit_base_patch16', modality='image', device='mps'))
    .map('img2', 'vec2', ops.image_text_embedding.clip(model_name='clip_vit_base_patch16', modality='image', device='mps'))
    .map('img3', 'vec3', ops.image_text_embedding.clip(model_name='clip_vit_base_patch16', modality='image', device='mps'))
    .map('img4', 'vec4', ops.image_text_embedding.clip(model_name='clip_vit_base_patch16', modality='image', device='mps'))
    .map(('vec1', 'vec2', 'vec3', 'vec4'), 'vec', lambda v1, v2, v3, v4: np.mean([v1, v2, v3, v4], axis=0))
    .map('vec', 'vec', lambda x: x / np.linalg.norm(x))
    .map(('frame_id', 'vec'), (), ops.ann_insert.milvus_client(collection_name=FRAME_4_RET_COLLECTION))
    .output('frame_id')
)


eight_frame_csv_loader = get_frame_loader_csv(8)
multi_8_frame_loader_pipeline = (
    pipe.input('csv_file')
    .flat_map('csv_file', ('frame_id', 'f_path_1', 'f_path_2', 'f_path_3', 'f_path_4', 'f_path_5', 'f_path_6', 'f_path_7', 'f_path_8'), eight_frame_csv_loader)
    .map('f_path_1', 'img1', ops.image_decode.cv2('rgb'))
    .map('f_path_2', 'img2', ops.image_decode.cv2('rgb'))
    .map('f_path_3', 'img3', ops.image_decode.cv2('rgb'))
    .map('f_path_4', 'img4', ops.image_decode.cv2('rgb'))
    .map('f_path_5', 'img5', ops.image_decode.cv2('rgb'))
    .map('f_path_6', 'img6', ops.image_decode.cv2('rgb'))
    .map('f_path_7', 'img7', ops.image_decode.cv2('rgb'))
    .map('f_path_8', 'img8', ops.image_decode.cv2('rgb'))
    
    .map('img1', 'vec1', ops.image_text_embedding.clip(model_name='clip_vit_base_patch16', modality='image', device='mps'))
    .map('img2', 'vec2', ops.image_text_embedding.clip(model_name='clip_vit_base_patch16', modality='image', device='mps'))
    .map('img3', 'vec3', ops.image_text_embedding.clip(model_name='clip_vit_base_patch16', modality='image', device='mps'))
    .map('img4', 'vec4', ops.image_text_embedding.clip(model_name='clip_vit_base_patch16', modality='image', device='mps'))
    .map('img5', 'vec5', ops.image_text_embedding.clip(model_name='clip_vit_base_patch16', modality='image', device='mps'))
    .map('img6', 'vec6', ops.image_text_embedding.clip(model_name='clip_vit_base_patch16', modality='image', device='mps'))
    .map('img7', 'vec7', ops.image_text_embedding.clip(model_name='clip_vit_base_patch16', modality='image', device='mps'))
    .map('img8', 'vec8', ops.image_text_embedding.clip(model_name='clip_vit_base_patch16', modality='image', device='mps'))
    .map(('vec1', 'vec2', 'vec3', 'vec4', 'vec5', 'vec6', 'vec7', 'vec8'), 'vec', lambda v1, v2, v3, v4, v5, v6, v7, v8: np.mean([v1, v2, v3, v4, v5, v6, v7, v8], axis=0))

    .map('vec', 'vec', lambda x: x / np.linalg.norm(x))
    .map(('frame_id', 'vec'), (), ops.ann_insert.milvus_client(collection_name=FRAME_8_RET_COLLECTION))
    .output('frame_id')
)
# Out:
# 2025-04-17 14:26:53,147 - 8454604864 - clip.py-clip:100 - WARNING: Gpu not available, use cpu
# 2025-04-17 14:26:53,194 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:53,235 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:53,280 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/model.safetensors HTTP/1.1" 404 0
# 2025-04-17 14:26:53,285 - 23280021504 - connectionpool.py-connectionpool:1049 - DEBUG: Starting new HTTPS connection (1): huggingface.co:443
# 2025-04-17 14:26:53,475 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:53,570 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:53,607 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:53,625 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16 HTTP/1.1" 200 3499
# 2025-04-17 14:26:53,719 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/processor_config.json HTTP/1.1" 404 0
# 2025-04-17 14:26:53,731 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/main HTTP/1.1" 200 3099
# 2025-04-17 14:26:53,759 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.json HTTP/1.1" 404 0
# 2025-04-17 14:26:53,789 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/discussions?p=0 HTTP/1.1" 200 6380
# 2025-04-17 14:26:53,794 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.jinja HTTP/1.1" 404 0
# 2025-04-17 14:26:53,890 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/refs%2Fpr%2F10 HTTP/1.1" 200 4064
# 2025-04-17 14:26:53,900 - 8454604864 - clip.py-clip:100 - WARNING: Gpu not available, use cpu
# 2025-04-17 14:26:53,940 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:53,949 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors.index.json HTTP/1.1" 404 0
# 2025-04-17 14:26:54,000 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:54,003 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors HTTP/1.1" 302 0
# 2025-04-17 14:26:54,045 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/model.safetensors HTTP/1.1" 404 0
# 2025-04-17 14:26:54,083 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16 HTTP/1.1" 200 3499
# 2025-04-17 14:26:54,172 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/main HTTP/1.1" 200 3099
# 2025-04-17 14:26:54,213 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:54,233 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/discussions?p=0 HTTP/1.1" 200 6380
# 2025-04-17 14:26:54,301 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:54,305 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/refs%2Fpr%2F10 HTTP/1.1" 200 4064
# 2025-04-17 14:26:54,330 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:54,400 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors.index.json HTTP/1.1" 404 0
# 2025-04-17 14:26:54,433 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors HTTP/1.1" 302 0
# 2025-04-17 14:26:54,467 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/processor_config.json HTTP/1.1" 404 0
# 2025-04-17 14:26:54,502 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.json HTTP/1.1" 404 0
# 2025-04-17 14:26:54,540 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.jinja HTTP/1.1" 404 0
# 2025-04-17 14:26:54,631 - 8454604864 - clip.py-clip:100 - WARNING: Gpu not available, use cpu
# 2025-04-17 14:26:54,661 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:54,692 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:54,727 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/model.safetensors HTTP/1.1" 404 0
# 2025-04-17 14:26:54,768 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16 HTTP/1.1" 200 3499
# 2025-04-17 14:26:54,858 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/main HTTP/1.1" 200 3099
# 2025-04-17 14:26:54,908 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:54,908 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/discussions?p=0 HTTP/1.1" 200 6380
# 2025-04-17 14:26:54,963 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/refs%2Fpr%2F10 HTTP/1.1" 200 4064
# 2025-04-17 14:26:54,996 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:55,002 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors.index.json HTTP/1.1" 404 0
# 2025-04-17 14:26:55,033 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors HTTP/1.1" 302 0
# 2025-04-17 14:26:55,053 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:55,156 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/processor_config.json HTTP/1.1" 404 0
# 2025-04-17 14:26:55,194 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.json HTTP/1.1" 404 0
# 2025-04-17 14:26:55,232 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.jinja HTTP/1.1" 404 0
# 2025-04-17 14:26:55,328 - 8454604864 - clip.py-clip:100 - WARNING: Gpu not available, use cpu
# 2025-04-17 14:26:55,368 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:55,399 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:55,439 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/model.safetensors HTTP/1.1" 404 0
# 2025-04-17 14:26:55,536 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16 HTTP/1.1" 200 3499
# 2025-04-17 14:26:55,617 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/main HTTP/1.1" 200 3099
# 2025-04-17 14:26:55,636 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:55,720 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:55,755 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:55,859 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/processor_config.json HTTP/1.1" 404 0
# 2025-04-17 14:26:55,902 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.json HTTP/1.1" 404 0
# 2025-04-17 14:26:55,949 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.jinja HTTP/1.1" 404 0
# 2025-04-17 14:26:56,088 - 8454604864 - clip.py-clip:100 - WARNING: Gpu not available, use cpu
# 2025-04-17 14:26:56,118 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:56,158 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:56,194 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/model.safetensors HTTP/1.1" 404 0
# 2025-04-17 14:26:56,199 - 23325650944 - connectionpool.py-connectionpool:1049 - DEBUG: Starting new HTTPS connection (1): huggingface.co:443
# 2025-04-17 14:26:56,338 - 23325650944 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16 HTTP/1.1" 200 3499
# 2025-04-17 14:26:56,359 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:56,404 - 23325650944 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/main HTTP/1.1" 200 3099
# 2025-04-17 14:26:56,457 - 23325650944 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/discussions?p=0 HTTP/1.1" 200 6380
# 2025-04-17 14:26:56,511 - 23325650944 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/refs%2Fpr%2F10 HTTP/1.1" 200 4064
# 2025-04-17 14:26:56,544 - 23325650944 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors.index.json HTTP/1.1" 404 0
# 2025-04-17 14:26:56,577 - 23325650944 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors HTTP/1.1" 302 0
# 2025-04-17 14:26:56,627 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/discussions?p=0 HTTP/1.1" 200 6380
# 2025-04-17 14:26:56,656 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:56,681 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/refs%2Fpr%2F10 HTTP/1.1" 200 4064
# 2025-04-17 14:26:56,688 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:56,763 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors.index.json HTTP/1.1" 404 0
# 2025-04-17 14:26:56,794 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/processor_config.json HTTP/1.1" 404 0
# 2025-04-17 14:26:56,795 - 23280021504 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors HTTP/1.1" 302 0
# 2025-04-17 14:26:56,832 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.json HTTP/1.1" 404 0
# 2025-04-17 14:26:56,866 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.jinja HTTP/1.1" 404 0
# 2025-04-17 14:26:56,958 - 8454604864 - clip.py-clip:100 - WARNING: Gpu not available, use cpu
# 2025-04-17 14:26:56,992 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:57,094 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:57,136 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/model.safetensors HTTP/1.1" 404 0
# 2025-04-17 14:26:57,140 - 23314067456 - connectionpool.py-connectionpool:1049 - DEBUG: Starting new HTTPS connection (1): huggingface.co:443
# 2025-04-17 14:26:57,204 - 23314067456 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16 HTTP/1.1" 200 3499
# 2025-04-17 14:26:57,272 - 23314067456 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/main HTTP/1.1" 200 3099
# 2025-04-17 14:26:57,317 - 23314067456 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/discussions?p=0 HTTP/1.1" 200 6380
# 2025-04-17 14:26:57,347 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:57,381 - 23314067456 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/refs%2Fpr%2F10 HTTP/1.1" 200 4064
# 2025-04-17 14:26:57,446 - 23314067456 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors.index.json HTTP/1.1" 404 0
# 2025-04-17 14:26:57,463 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:57,484 - 23314067456 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors HTTP/1.1" 302 0
# 2025-04-17 14:26:57,498 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:57,611 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/processor_config.json HTTP/1.1" 404 0
# 2025-04-17 14:26:57,662 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.json HTTP/1.1" 404 0
# 2025-04-17 14:26:57,800 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.jinja HTTP/1.1" 404 0
# 2025-04-17 14:26:57,894 - 8454604864 - clip.py-clip:100 - WARNING: Gpu not available, use cpu
# 2025-04-17 14:26:57,927 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:57,959 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:58,005 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/model.safetensors HTTP/1.1" 404 0
# 2025-04-17 14:26:58,008 - 23332990976 - connectionpool.py-connectionpool:1049 - DEBUG: Starting new HTTPS connection (1): huggingface.co:443
# 2025-04-17 14:26:58,070 - 23332990976 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16 HTTP/1.1" 200 3499
# 2025-04-17 14:26:58,136 - 23332990976 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/main HTTP/1.1" 200 3099
# 2025-04-17 14:26:58,177 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:58,272 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:58,295 - 23332990976 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/discussions?p=0 HTTP/1.1" 200 6380
# 2025-04-17 14:26:58,305 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:58,373 - 23332990976 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/refs%2Fpr%2F10 HTTP/1.1" 200 4064
# 2025-04-17 14:26:58,407 - 23332990976 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors.index.json HTTP/1.1" 404 0
# 2025-04-17 14:26:58,412 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/processor_config.json HTTP/1.1" 404 0
# 2025-04-17 14:26:58,440 - 23332990976 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors HTTP/1.1" 302 0
# 2025-04-17 14:26:58,445 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.json HTTP/1.1" 404 0
# 2025-04-17 14:26:58,482 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.jinja HTTP/1.1" 404 0
# 2025-04-17 14:26:58,573 - 8454604864 - clip.py-clip:100 - WARNING: Gpu not available, use cpu
# 2025-04-17 14:26:58,607 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:58,640 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:58,693 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/model.safetensors HTTP/1.1" 404 0
# 2025-04-17 14:26:58,765 - 23332990976 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16 HTTP/1.1" 200 3499
# 2025-04-17 14:26:58,820 - 23332990976 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/main HTTP/1.1" 200 3099
# 2025-04-17 14:26:58,862 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:58,901 - 23332990976 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/discussions?p=0 HTTP/1.1" 200 6380
# 2025-04-17 14:26:58,946 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:58,962 - 23332990976 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/refs%2Fpr%2F10 HTTP/1.1" 200 4064
# 2025-04-17 14:26:58,978 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:26:59,048 - 23332990976 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors.index.json HTTP/1.1" 404 0
# 2025-04-17 14:26:59,080 - 23332990976 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors HTTP/1.1" 302 0
# 2025-04-17 14:27:00,086 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/processor_config.json HTTP/1.1" 404 0
# 2025-04-17 14:27:00,125 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.json HTTP/1.1" 404 0
# 2025-04-17 14:27:00,165 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.jinja HTTP/1.1" 404 0
# 2025-04-17 14:27:00,253 - 8454604864 - clip.py-clip:100 - WARNING: Gpu not available, use cpu
# 2025-04-17 14:27:00,287 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:00,316 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:00,354 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/model.safetensors HTTP/1.1" 404 0
# 2025-04-17 14:27:00,358 - 26839052288 - connectionpool.py-connectionpool:1049 - DEBUG: Starting new HTTPS connection (1): huggingface.co:443
# 2025-04-17 14:27:00,419 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16 HTTP/1.1" 200 3499
# 2025-04-17 14:27:00,484 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/main HTTP/1.1" 200 3099
# 2025-04-17 14:27:00,529 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:00,610 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:00,656 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:00,755 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/processor_config.json HTTP/1.1" 404 0
# 2025-04-17 14:27:00,787 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.json HTTP/1.1" 404 0
# 2025-04-17 14:27:00,809 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/discussions?p=0 HTTP/1.1" 200 6380
# 2025-04-17 14:27:00,822 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.jinja HTTP/1.1" 404 0
# 2025-04-17 14:27:00,908 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/refs%2Fpr%2F10 HTTP/1.1" 200 4064
# 2025-04-17 14:27:00,916 - 8454604864 - clip.py-clip:100 - WARNING: Gpu not available, use cpu
# 2025-04-17 14:27:00,947 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:00,948 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors.index.json HTTP/1.1" 404 0
# 2025-04-17 14:27:00,978 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:00,984 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors HTTP/1.1" 302 0
# 2025-04-17 14:27:01,021 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/model.safetensors HTTP/1.1" 404 0
# 2025-04-17 14:27:01,059 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16 HTTP/1.1" 200 3499
# 2025-04-17 14:27:01,135 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/main HTTP/1.1" 200 3099
# 2025-04-17 14:27:01,326 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:01,355 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/discussions?p=0 HTTP/1.1" 200 6380
# 2025-04-17 14:27:01,420 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:01,435 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/refs%2Fpr%2F10 HTTP/1.1" 200 4064
# 2025-04-17 14:27:01,459 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:01,536 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors.index.json HTTP/1.1" 404 0
# 2025-04-17 14:27:01,576 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/processor_config.json HTTP/1.1" 404 0
# 2025-04-17 14:27:01,580 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors HTTP/1.1" 302 0
# 2025-04-17 14:27:01,634 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.json HTTP/1.1" 404 0
# 2025-04-17 14:27:01,670 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.jinja HTTP/1.1" 404 0
# 2025-04-17 14:27:01,760 - 8454604864 - clip.py-clip:100 - WARNING: Gpu not available, use cpu
# 2025-04-17 14:27:01,793 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:01,826 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:01,863 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/model.safetensors HTTP/1.1" 404 0
# 2025-04-17 14:27:01,906 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16 HTTP/1.1" 200 3499
# 2025-04-17 14:27:02,207 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/main HTTP/1.1" 200 3099
# 2025-04-17 14:27:02,276 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/discussions?p=0 HTTP/1.1" 200 6380
# 2025-04-17 14:27:02,317 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:02,335 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/refs%2Fpr%2F10 HTTP/1.1" 200 4064
# 2025-04-17 14:27:02,384 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors.index.json HTTP/1.1" 404 0
# 2025-04-17 14:27:02,409 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:02,414 - 26839052288 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors HTTP/1.1" 302 0
# 2025-04-17 14:27:02,447 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:02,665 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/processor_config.json HTTP/1.1" 404 0
# 2025-04-17 14:27:02,698 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.json HTTP/1.1" 404 0
# 2025-04-17 14:27:02,731 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.jinja HTTP/1.1" 404 0
# 2025-04-17 14:27:02,824 - 8454604864 - clip.py-clip:100 - WARNING: Gpu not available, use cpu
# 2025-04-17 14:27:02,853 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:02,887 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:02,942 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/model.safetensors HTTP/1.1" 404 0
# 2025-04-17 14:27:02,948 - 31222345728 - connectionpool.py-connectionpool:1049 - DEBUG: Starting new HTTPS connection (1): huggingface.co:443
# 2025-04-17 14:27:03,034 - 31222345728 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16 HTTP/1.1" 200 3499
# 2025-04-17 14:27:03,097 - 31222345728 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/main HTTP/1.1" 200 3099
# 2025-04-17 14:27:03,166 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:03,185 - 31222345728 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/discussions?p=0 HTTP/1.1" 200 6380
# 2025-04-17 14:27:03,254 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:03,271 - 31222345728 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/refs%2Fpr%2F10 HTTP/1.1" 200 4064
# 2025-04-17 14:27:03,289 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:27:03,371 - 31222345728 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors.index.json HTTP/1.1" 404 0
# 2025-04-17 14:27:03,391 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/processor_config.json HTTP/1.1" 404 0
# 2025-04-17 14:27:03,427 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.json HTTP/1.1" 404 0
# 2025-04-17 14:27:03,432 - 31222345728 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors HTTP/1.1" 302 0
# 2025-04-17 14:27:03,459 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.jinja HTTP/1.1" 404 0

# %%
# Run both loader pipelines
multi_4_frame_loader_pipeline(MSRVTT_SAMPLES_WITH_4_FRAMES)
print('4 frame loader pipeline finished.')
multi_8_frame_loader_pipeline(MSRVTT_SAMPLES_WITH_8_FRAMES)
print('8 frame loader pipeline finished.')
# Out:
# 2025-04-17 14:27:06,803 - 17664241664 - node.py-node:167 - INFO: Begin to run Node-_input
# 2025-04-17 14:27:06,810 - 17697894400 - node.py-node:167 - INFO: Begin to run Node-read_frame_loader_csv-0
# 2025-04-17 14:27:06,811 - 17664241664 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-1
# 2025-04-17 14:27:06,815 - 17681068032 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-2
# 2025-04-17 14:27:06,820 - 17731547136 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-3
# 2025-04-17 14:27:06,852 - 17714720768 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-4
# 2025-04-17 14:27:06,856 - 17765199872 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-5
# 2025-04-17 14:27:06,874 - 17748373504 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-6
# 2025-04-17 14:27:06,885 - 17782026240 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-7
# 2025-04-17 14:27:06,895 - 17697894400 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-8
# 2025-04-17 14:27:06,899 - 17798852608 - node.py-node:167 - INFO: Begin to run Node-lambda-9
# 2025-04-17 14:27:06,902 - 17815678976 - node.py-node:167 - INFO: Begin to run Node-lambda-10
# 2025-04-17 14:27:06,903 - 17832505344 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-11
# 2025-04-17 14:27:06,905 - 17849331712 - node.py-node:167 - INFO: Begin to run Node-_output
# 2025-04-17 14:30:16,404 - 18093535232 - node.py-node:167 - INFO: Begin to run Node-_input
# 2025-04-17 14:30:16,406 - 18127187968 - node.py-node:167 - INFO: Begin to run Node-read_frame_loader_csv-0
# 2025-04-17 14:30:16,406 - 18093535232 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-1
# 2025-04-17 14:30:16,408 - 18144014336 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-2
# 2025-04-17 14:30:16,409 - 18110361600 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-3
# 2025-04-17 14:30:16,415 - 18160840704 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-4
# 2025-04-17 14:30:16,427 - 18177667072 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-5
# 2025-04-17 14:30:16,431 - 18211319808 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-6
# 2025-04-17 14:30:16,457 - 18127187968 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-7
# 2025-04-17 14:30:16,458 - 18228146176 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-8
# 2025-04-17 14:30:16,459 - 18244972544 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-9
# 2025-04-17 14:30:16,462 - 18194493440 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-10
# 2025-04-17 14:30:16,464 - 18432946176 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-11
# 2025-04-17 14:30:16,466 - 18449772544 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-12
# 2025-04-17 14:30:16,469 - 18466598912 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-13
# 2025-04-17 14:30:16,471 - 18500251648 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-14
# 2025-04-17 14:30:16,473 - 18483425280 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-15
# 2025-04-17 14:30:16,477 - 18517078016 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-16
# 4 frame loader pipeline finished.
# 2025-04-17 14:30:18,703 - 18093535232 - node.py-node:167 - INFO: Begin to run Node-lambda-17
# 2025-04-17 14:30:18,707 - 18144014336 - node.py-node:167 - INFO: Begin to run Node-lambda-18
# 2025-04-17 14:30:18,709 - 18110361600 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-19
# 2025-04-17 14:30:18,712 - 18160840704 - node.py-node:167 - INFO: Begin to run Node-_output
# 8 frame loader pipeline finished.
# 2025-04-17 14:55:51,518 - 17664241664 - node.py-node:167 - INFO: Begin to run Node-_input
# 2025-04-17 14:55:51,520 - 17681068032 - node.py-node:167 - INFO: Begin to run Node-read_frame_loader_csv-0
# 2025-04-17 14:55:51,523 - 17731547136 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-1
# 2025-04-17 14:55:51,524 - 17714720768 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-3
# 2025-04-17 14:55:51,524 - 17664241664 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-4
# 2025-04-17 14:55:51,524 - 17765199872 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-5
# 2025-04-17 14:55:51,525 - 17748373504 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-6
# 2025-04-17 14:55:51,525 - 17782026240 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-7
# 2025-04-17 14:55:51,527 - 17697894400 - node.py-node:167 - INFO: Begin to run Node-lambda-9
# 2025-04-17 14:55:51,527 - 17798852608 - node.py-node:167 - INFO: Begin to run Node-lambda-10
# 2025-04-17 14:55:51,529 - 17815678976 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-11
# 2025-04-17 14:55:51,530 - 17832505344 - node.py-node:167 - INFO: Begin to run Node-_output
# 2025-04-17 14:55:51,534 - 17681068032 - node.py-node:142 - INFO: read_frame_loader_csv-0 ends with status: NodeStatus.FAILED
# 2025-04-17 14:56:50,378 - 17849331712 - node.py-node:167 - INFO: Begin to run Node-_input
# 2025-04-17 14:56:50,378 - 17681068032 - node.py-node:167 - INFO: Begin to run Node-read_frame_loader_csv-0
# 2025-04-17 14:56:50,379 - 17731547136 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-1
# 2025-04-17 14:56:50,379 - 17714720768 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-3
# 2025-04-17 14:56:50,379 - 17664241664 - node.py-node:167 - INFO: Begin to run Node-image-decode/cv2-4
# 2025-04-17 14:56:50,379 - 17765199872 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-5
# 2025-04-17 14:56:50,379 - 17748373504 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-6
# 2025-04-17 14:56:50,379 - 17782026240 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-7
# 2025-04-17 14:56:50,379 - 17697894400 - node.py-node:167 - INFO: Begin to run Node-lambda-9
# 2025-04-17 14:56:50,379 - 17798852608 - node.py-node:167 - INFO: Begin to run Node-lambda-10
# 2025-04-17 14:56:50,379 - 17849331712 - node.py-node:167 - INFO: Begin to run Node-ann-insert/milvus-client-11
# 2025-04-17 14:56:50,379 - 17815678976 - node.py-node:167 - INFO: Begin to run Node-_output
# 2025-04-17 14:56:50,381 - 17681068032 - node.py-node:142 - INFO: read_frame_loader_csv-0 ends with status: NodeStatus.FAILED

# %%
def read_frame_search_csv(csv_file):
    with open(csv_file, 'r', encoding='utf-8-sig') as f:
        data = csv.DictReader(f)
        for line in data:
            yield line['frame_id'], line['sentence']
            
multi_4_frame_search_pipeline = (
    pipe.input('csv_file')
    .flat_map('csv_file', ('rel_frame_id', 'query'), read_frame_search_csv)
    .map('query', 'vec', ops.image_text_embedding.clip(model_name='clip_vit_base_patch16', modality='text', device='mps'))
    .map('vec', 'vec', lambda x: x / np.linalg.norm(x))
    .map('vec', 'top15_raw_res', ops.ann_search.milvus_client(collection_name=FRAME_4_RET_COLLECTION, limit=15))
    .map('top15_raw_res', ('top1', 'top5', 'top10', 'top15'), lambda x: (x[:1], x[:5], x[:10], x[:15]))
    .output('rel_frame_id', 'query', 'top1', 'top5', 'top10', 'top15')
)

multi_8_frame_search_pipeline = (
    pipe.input('csv_file')
    .flat_map('csv_file', ('rel_frame_id', 'query'), read_frame_search_csv)
    .map('query', 'vec', ops.image_text_embedding.clip(model_name='clip_vit_base_patch16', modality='text', device='mps'))
    .map('vec', 'vec', lambda x: x / np.linalg.norm(x))
    .map('vec', 'top15_raw_res', ops.ann_search.milvus_client(collection_name=FRAME_8_RET_COLLECTION, limit=15))
    .map('top15_raw_res', ('top1', 'top5', 'top10', 'top15'), lambda x: (x[:1], x[:5], x[:10], x[:15]))
    .output('rel_frame_id', 'query', 'top1', 'top5', 'top10', 'top15')
)
# Out:
# 2025-04-17 14:46:50,531 - 8454604864 - clip.py-clip:100 - WARNING: Gpu not available, use cpu
# 2025-04-17 14:46:50,584 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:46:50,666 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:46:50,708 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/model.safetensors HTTP/1.1" 404 0
# 2025-04-17 14:46:50,713 - 13520564224 - connectionpool.py-connectionpool:1049 - DEBUG: Starting new HTTPS connection (1): huggingface.co:443
# 2025-04-17 14:46:50,767 - 13520564224 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16 HTTP/1.1" 200 3499
# 2025-04-17 14:46:50,838 - 13520564224 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/main HTTP/1.1" 200 3099
# 2025-04-17 14:46:50,894 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:46:51,004 - 13520564224 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/discussions?p=0 HTTP/1.1" 200 6380
# 2025-04-17 14:46:51,007 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 2025-04-17 14:46:51,041 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:46:51,061 - 13520564224 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/refs%2Fpr%2F10 HTTP/1.1" 200 4064
# 2025-04-17 14:46:51,153 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/processor_config.json HTTP/1.1" 404 0
# 2025-04-17 14:46:51,155 - 13520564224 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors.index.json HTTP/1.1" 404 0
# 2025-04-17 14:46:51,186 - 13520564224 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors HTTP/1.1" 302 0
# 2025-04-17 14:46:51,196 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.json HTTP/1.1" 404 0
# 2025-04-17 14:46:51,232 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.jinja HTTP/1.1" 404 0
# 2025-04-17 14:46:51,374 - 8454604864 - clip.py-clip:100 - WARNING: Gpu not available, use cpu
# 2025-04-17 14:46:51,408 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:46:51,438 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:46:51,471 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/model.safetensors HTTP/1.1" 404 0
# 2025-04-17 14:46:51,476 - 13453258752 - connectionpool.py-connectionpool:1049 - DEBUG: Starting new HTTPS connection (1): huggingface.co:443
# 2025-04-17 14:46:51,532 - 13453258752 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16 HTTP/1.1" 200 3499
# 2025-04-17 14:46:51,582 - 13453258752 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/main HTTP/1.1" 200 3099
# 2025-04-17 14:46:51,646 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:46:51,664 - 13453258752 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/discussions?p=0 HTTP/1.1" 200 6380
# 2025-04-17 14:46:51,733 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 2025-04-17 14:46:51,750 - 13453258752 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/refs%2Fpr%2F10 HTTP/1.1" 200 4064
# 2025-04-17 14:46:51,765 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:46:51,837 - 13453258752 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors.index.json HTTP/1.1" 404 0
# 2025-04-17 14:46:51,872 - 13453258752 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors HTTP/1.1" 302 0
# 2025-04-17 14:46:51,874 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/processor_config.json HTTP/1.1" 404 0
# 2025-04-17 14:46:51,923 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.json HTTP/1.1" 404 0
# 2025-04-17 14:46:51,957 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.jinja HTTP/1.1" 404 0

# %%
multi_4_frame_msr_results = DataCollection(multi_4_frame_search_pipeline(MSRVTT_SAMPLES_WITH_4_FRAMES))
multi_4_frame_msr_results.show()
# Out:
# 2025-04-17 14:46:52,278 - 13473230848 - node.py-node:167 - INFO: Begin to run Node-_input
# 2025-04-17 14:46:52,280 - 13490057216 - node.py-node:167 - INFO: Begin to run Node-read_frame_search_csv-0
# 2025-04-17 14:46:52,281 - 13473230848 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-1
# 2025-04-17 14:46:52,282 - 13523709952 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2025-04-17 14:46:52,283 - 13506883584 - node.py-node:167 - INFO: Begin to run Node-ann-search/milvus-client-3
# 2025-04-17 14:46:52,287 - 13540536320 - node.py-node:167 - INFO: Begin to run Node-lambda-4
# 2025-04-17 14:46:52,289 - 15042899968 - node.py-node:167 - INFO: Begin to run Node-_output
# <table style="border-collapse: collapse;"><tr><th style="text-align: center; font-size: 130%; border: none;">rel_frame_id</th> <th style="text-align: center; font-size: 130%; border: none;">query</th> <th style="text-align: center; font-size: 130%; border: none;">top1</th> <th style="text-align: center; font-size: 130%; border: none;">top5</th> <th style="text-align: center; font-size: 130%; border: none;">top10</th> <th style="text-align: center; font-size: 130%; border: none;">top15</th></tr>
# <tr><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">video7579</td><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">a girl wearing red top and black trouser is putting a sweater on a dog</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7579, 1.3646539449691772]] len=1</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7579, 1.3646539449691772],[9451, 1.4305797815322876],[9603, 1.4387223720550537],[9405, 1.4451756477355957],...] len=5</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7579, 1.3646539449691772],[9451, 1.4305797815322876],[9603, 1.4387223720550537],[9405, 1.4451756477355957],...] len=10</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7579, 1.3646539449691772],[9451, 1.4305797815322876],[9603, 1.4387223720550537],[9405, 1.4451756477355957],...] len=15</td></tr>
# <tr><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">video7725</td><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">young people sit around the edges of a room clapping and raising their arms while others dance in the center during a party</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[8441, 1.4233133792877197]] len=1</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[8441, 1.4233133792877197],[7444, 1.4263453483581543],[7725, 1.4346461296081543],[8339, 1.4430490732192993],...] len=5</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[8441, 1.4233133792877197],[7444, 1.4263453483581543],[7725, 1.4346461296081543],[8339, 1.4430490732192993],...] len=10</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[8441, 1.4233133792877197],[7444, 1.4263453483581543],[7725, 1.4346461296081543],[8339, 1.4430490732192993],...] len=15</td></tr>
# <tr><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">video9258</td><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">a person is using a phone</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[9257, 1.4228744506835938]] len=1</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[9257, 1.4228744506835938],[9697, 1.4255503416061401],[9829, 1.4330558776855469],[9258, 1.4334453344345093],...] len=5</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[9257, 1.4228744506835938],[9697, 1.4255503416061401],[9829, 1.4330558776855469],[9258, 1.4334453344345093],...] len=10</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[9257, 1.4228744506835938],[9697, 1.4255503416061401],[9829, 1.4330558776855469],[9258, 1.4334453344345093],...] len=15</td></tr>
# <tr><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">video7365</td><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">cartoon people are eating at a restaurant</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[9777, 1.3961538076400757]] len=1</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[9777, 1.3961538076400757],[7365, 1.4227542877197266],[9537, 1.4308252334594727],[7741, 1.4411455392837524],...] len=5</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[9777, 1.3961538076400757],[7365, 1.4227542877197266],[9537, 1.4308252334594727],[7741, 1.4411455392837524],...] len=10</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[9777, 1.3961538076400757],[7365, 1.4227542877197266],[9537, 1.4308252334594727],[7741, 1.4411455392837524],...] len=15</td></tr>
# <tr><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">video8068</td><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">a woman on a couch talks to a a man</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7724, 1.3794373273849487]] len=1</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7724, 1.3794373273849487],[7234, 1.4042013883590698],[7341, 1.4079279899597168],[9347, 1.408487319946289],...] len=5</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7724, 1.3794373273849487],[7234, 1.4042013883590698],[7341, 1.4079279899597168],[9347, 1.408487319946289],...] len=10</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7724, 1.3794373273849487],[7234, 1.4042013883590698],[7341, 1.4079279899597168],[9347, 1.408487319946289],...] len=15</td></tr></table>

# %%
multi_8_frame_msr_results = DataCollection(multi_8_frame_search_pipeline(MSRVTT_SAMPLES_WITH_8_FRAMES))
multi_8_frame_msr_results.show()
# Out:
# 2025-04-17 14:47:21,407 - 13456404480 - node.py-node:167 - INFO: Begin to run Node-_input
# 2025-04-17 14:47:21,409 - 14935945216 - node.py-node:167 - INFO: Begin to run Node-read_frame_search_csv-0
# 2025-04-17 14:47:21,410 - 13456404480 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-1
# 2025-04-17 14:47:21,411 - 15059726336 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2025-04-17 14:47:21,412 - 15093379072 - node.py-node:167 - INFO: Begin to run Node-ann-search/milvus-client-3
# 2025-04-17 14:47:21,413 - 15110205440 - node.py-node:167 - INFO: Begin to run Node-lambda-4
# 2025-04-17 14:47:21,416 - 15127031808 - node.py-node:167 - INFO: Begin to run Node-_output
# <table style="border-collapse: collapse;"><tr><th style="text-align: center; font-size: 130%; border: none;">rel_frame_id</th> <th style="text-align: center; font-size: 130%; border: none;">query</th> <th style="text-align: center; font-size: 130%; border: none;">top1</th> <th style="text-align: center; font-size: 130%; border: none;">top5</th> <th style="text-align: center; font-size: 130%; border: none;">top10</th> <th style="text-align: center; font-size: 130%; border: none;">top15</th></tr>
# <tr><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">video7579</td><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">a girl wearing red top and black trouser is putting a sweater on a dog</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7579, 1.360194444656372]] len=1</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7579, 1.360194444656372],[9451, 1.4077376127243042],[7730, 1.4435832500457764],[9034, 1.4514113664627075],...] len=5</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7579, 1.360194444656372],[9451, 1.4077376127243042],[7730, 1.4435832500457764],[9034, 1.4514113664627075],...] len=10</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7579, 1.360194444656372],[9451, 1.4077376127243042],[7730, 1.4435832500457764],[9034, 1.4514113664627075],...] len=15</td></tr>
# <tr><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">video7725</td><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">young people sit around the edges of a room clapping and raising their arms while others dance in the center during a party</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7725, 1.3989646434783936]] len=1</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7725, 1.3989646434783936],[7444, 1.4208428859710693],[8556, 1.4406566619873047],[8441, 1.4462244510650635],...] len=5</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7725, 1.3989646434783936],[7444, 1.4208428859710693],[8556, 1.4406566619873047],[8441, 1.4462244510650635],...] len=10</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7725, 1.3989646434783936],[7444, 1.4208428859710693],[8556, 1.4406566619873047],[8441, 1.4462244510650635],...] len=15</td></tr>
# <tr><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">video9258</td><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">a person is using a phone</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[9257, 1.422074317932129]] len=1</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[9257, 1.422074317932129],[9697, 1.4267330169677734],[9258, 1.4296905994415283],[8945, 1.4394712448120117],...] len=5</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[9257, 1.422074317932129],[9697, 1.4267330169677734],[9258, 1.4296905994415283],[8945, 1.4394712448120117],...] len=10</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[9257, 1.422074317932129],[9697, 1.4267330169677734],[9258, 1.4296905994415283],[8945, 1.4394712448120117],...] len=15</td></tr>
# <tr><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">video7365</td><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">cartoon people are eating at a restaurant</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[9777, 1.3951191902160645]] len=1</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[9777, 1.3951191902160645],[9537, 1.4230724573135376],[7365, 1.4236586093902588],[7741, 1.4339861869812012],...] len=5</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[9777, 1.3951191902160645],[9537, 1.4230724573135376],[7365, 1.4236586093902588],[7741, 1.4339861869812012],...] len=10</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[9777, 1.3951191902160645],[9537, 1.4230724573135376],[7365, 1.4236586093902588],[7741, 1.4339861869812012],...] len=15</td></tr>
# <tr><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">video8068</td><td style="text-align: center; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">a woman on a couch talks to a a man</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7724, 1.3635627031326294]] len=1</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7724, 1.3635627031326294],[7341, 1.4104743003845215],[9347, 1.4147610664367676],[7685, 1.4171432256698608],...] len=5</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7724, 1.3635627031326294],[7341, 1.4104743003845215],[9347, 1.4147610664367676],[7685, 1.4171432256698608],...] len=10</td><td style="text-align: left; vertical-align: top; border-right: solid 1px #D3D3D3; border-left: solid 1px #D3D3D3; ">[[7724, 1.3635627031326294],[7341, 1.4104743003845215],[9347, 1.4147610664367676],[7685, 1.4171432256698608],...] len=15</td></tr></table>

# %%
multi_4_frame_msr_results_df = twohee_data_col_to_df(multi_4_frame_msr_results)
multi_4_frame_msr_results_df.to_csv('query_results/multi_4_frame_queries_msrvtt.csv', index=False)
multi_4_frame_msr_results_df
# Out:
#     rel_frame_id                                              query  \
# 0      video7579  a girl wearing red top and black trouser is pu...
# 1      video7725  young people sit around the edges of a room cl...
# 2      video9258                          a person is using a phone
# 3      video7365          cartoon people are eating at a restaurant
# 4      video8068                a woman on a couch talks to a a man
# ..           ...                                                ...
# 995    video7034  man in black shirt is holding a baby upside do...
# 996    video7568  the queen of england is seen walking with an e...
# 997    video7979                       people talking about a fight
# 998    video7356  a vehicle with details on what comes with it b...
# 999    video8578      a man is commentating while playing minecraft
#
#                              top1  \
# 0    [[7579, 1.3646539449691772]]
# 1    [[8441, 1.4233133792877197]]
# 2    [[9257, 1.4228744506835938]]
# 3    [[9777, 1.3961538076400757]]
# 4    [[7724, 1.3794373273849487]]
# ..                            ...
# 995  [[9885, 1.4678269624710083]]
# 996  [[7568, 1.2751219272613525]]
# 997  [[7211, 1.4365811347961426]]
# 998  [[7356, 1.3352746963500977]]
# 999    [[8077, 1.35731041431427]]
#
#                                                   top5  \
# 0    [[7579, 1.3646539449691772], [9451, 1.43057978...
# 1    [[8441, 1.4233133792877197], [7444, 1.42634534...
# 2    [[9257, 1.4228744506835938], [9697, 1.42555034...
# 3    [[9777, 1.3961538076400757], [7365, 1.42275428...
# 4    [[7724, 1.3794373273849487], [7234, 1.40420138...
# ..                                                 ...
# 995  [[9885, 1.4678269624710083], [9320, 1.47455167...
# 996  [[7568, 1.2751219272613525], [7116, 1.45783209...
# 997  [[7211, 1.4365811347961426], [7501, 1.43993902...
# 998  [[7356, 1.3352746963500977], [8819, 1.39669334...
# 999  [[8077, 1.35731041431427], [8931, 1.3581938743...
#
#                                                  top10  \
# 0    [[7579, 1.3646539449691772], [9451, 1.43057978...
# 1    [[8441, 1.4233133792877197], [7444, 1.42634534...
# 2    [[9257, 1.4228744506835938], [9697, 1.42555034...
# 3    [[9777, 1.3961538076400757], [7365, 1.42275428...
# 4    [[7724, 1.3794373273849487], [7234, 1.40420138...
# ..                                                 ...
# 995  [[9885, 1.4678269624710083], [9320, 1.47455167...
# 996  [[7568, 1.2751219272613525], [7116, 1.45783209...
# 997  [[7211, 1.4365811347961426], [7501, 1.43993902...
# 998  [[7356, 1.3352746963500977], [8819, 1.39669334...
# 999  [[8077, 1.35731041431427], [8931, 1.3581938743...
#
#                                                  top15  ground_truth
# 0    [[7579, 1.3646539449691772], [9451, 1.43057978...          7579
# 1    [[8441, 1.4233133792877197], [7444, 1.42634534...          7725
# 2    [[9257, 1.4228744506835938], [9697, 1.42555034...          9258
# 3    [[9777, 1.3961538076400757], [7365, 1.42275428...          7365
# 4    [[7724, 1.3794373273849487], [7234, 1.40420138...          8068
# ..                                                 ...           ...
# 995  [[9885, 1.4678269624710083], [9320, 1.47455167...          7034
# 996  [[7568, 1.2751219272613525], [7116, 1.45783209...          7568
# 997  [[7211, 1.4365811347961426], [7501, 1.43993902...          7979
# 998  [[7356, 1.3352746963500977], [8819, 1.39669334...          7356
# 999  [[8077, 1.35731041431427], [8931, 1.3581938743...          8578
#
# [1000 rows x 7 columns]

# %%
multi_8_frame_msr_results_df = twohee_data_col_to_df(multi_8_frame_msr_results)
multi_8_frame_msr_results_df.to_csv('query_results/multi_8_frame_queries_msrvtt.csv', index=False)
multi_8_frame_msr_results_df
# Out:
#     rel_frame_id                                              query  \
# 0      video7579  a girl wearing red top and black trouser is pu...
# 1      video7725  young people sit around the edges of a room cl...
# 2      video9258                          a person is using a phone
# 3      video7365          cartoon people are eating at a restaurant
# 4      video8068                a woman on a couch talks to a a man
# ..           ...                                                ...
# 995    video7034  man in black shirt is holding a baby upside do...
# 996    video7568  the queen of england is seen walking with an e...
# 997    video7979                       people talking about a fight
# 998    video7356  a vehicle with details on what comes with it b...
# 999    video8578      a man is commentating while playing minecraft
#
#                              top1  \
# 0     [[7579, 1.360194444656372]]
# 1    [[7725, 1.3989646434783936]]
# 2     [[9257, 1.422074317932129]]
# 3    [[9777, 1.3951191902160645]]
# 4    [[7724, 1.3635627031326294]]
# ..                            ...
# 995  [[9522, 1.4664983749389648]]
# 996  [[7568, 1.2713391780853271]]
# 997  [[7211, 1.4263927936553955]]
# 998  [[7356, 1.3739084005355835]]
# 999  [[8931, 1.3309963941574097]]
#
#                                                   top5  \
# 0    [[7579, 1.360194444656372], [9451, 1.407737612...
# 1    [[7725, 1.3989646434783936], [7444, 1.42084288...
# 2    [[9257, 1.422074317932129], [9697, 1.426733016...
# 3    [[9777, 1.3951191902160645], [9537, 1.42307245...
# 4    [[7724, 1.3635627031326294], [7341, 1.41047430...
# ..                                                 ...
# 995  [[9522, 1.4664983749389648], [9320, 1.47163987...
# 996  [[7568, 1.2713391780853271], [7116, 1.43614828...
# 997  [[7211, 1.4263927936553955], [7835, 1.44549965...
# 998  [[7356, 1.3739084005355835], [9358, 1.39286637...
# 999  [[8931, 1.3309963941574097], [8313, 1.34997975...
#
#                                                  top10  \
# 0    [[7579, 1.360194444656372], [9451, 1.407737612...
# 1    [[7725, 1.3989646434783936], [7444, 1.42084288...
# 2    [[9257, 1.422074317932129], [9697, 1.426733016...
# 3    [[9777, 1.3951191902160645], [9537, 1.42307245...
# 4    [[7724, 1.3635627031326294], [7341, 1.41047430...
# ..                                                 ...
# 995  [[9522, 1.4664983749389648], [9320, 1.47163987...
# 996  [[7568, 1.2713391780853271], [7116, 1.43614828...
# 997  [[7211, 1.4263927936553955], [7835, 1.44549965...
# 998  [[7356, 1.3739084005355835], [9358, 1.39286637...
# 999  [[8931, 1.3309963941574097], [8313, 1.34997975...
#
#                                                  top15  ground_truth
# 0    [[7579, 1.360194444656372], [9451, 1.407737612...          7579
# 1    [[7725, 1.3989646434783936], [7444, 1.42084288...          7725
# 2    [[9257, 1.422074317932129], [9697, 1.426733016...          9258
# 3    [[9777, 1.3951191902160645], [9537, 1.42307245...          7365
# 4    [[7724, 1.3635627031326294], [7341, 1.41047430...          8068
# ..                                                 ...           ...
# 995  [[9522, 1.4664983749389648], [9320, 1.47163987...          7034
# 996  [[7568, 1.2713391780853271], [7116, 1.43614828...          7568
# 997  [[7211, 1.4263927936553955], [7835, 1.44549965...          7979
# 998  [[7356, 1.3739084005355835], [9358, 1.39286637...          7356
# 999  [[8931, 1.3309963941574097], [8313, 1.34997975...          8578
#
# [1000 rows x 7 columns]

# %%
# Get eval metrics
from pprint import pprint
print("Metrics for 4 frame results")
pprint(get_all_eval_scores(multi_4_frame_msr_results_df))
print("Metrics for 8 frame results")
pprint(get_all_eval_scores(multi_8_frame_msr_results_df))
# Out:
# Metrics for 4 frame results
# {'map': 0.4118039682539681,
#  'ndcg@1': 0.311,
#  'ndcg@10': 0.46854068360509477,
#  'ndcg@5': 0.4313712173413061,
#  'recall@1': 0.311,
#  'recall@10': 0.651,
#  'recall@5': 0.537}
# Metrics for 8 frame results
# {'map': 0.42762857142857114,
#  'ndcg@1': 0.332,
#  'ndcg@10': 0.48185493150879904,
#  'ndcg@5': 0.44768332562758373,
#  'recall@1': 0.332,
#  'recall@10': 0.656,
#  'recall@5': 0.551}

# %% [markdown]
# # Try evaluation against queries from FIRE benchmark

# %% [markdown]
# We are working with a sample of MSR-VTT and our evaluation pipeline supports only one relevant query per video, hence we need to filter the full FIRE benchmark to only include videos we have sampled and ones with a single relevant result.

# %% [markdown]
# FIRE_BENCHMARK_Q_JUDGEMENTS is created in the notebook `./clean_fire_judgements.ipynb`

# %%
# Run query pipeline using FIRE


# CSV parser function and pipeline recreated since the FIRE csv uses `video_id` instead of `frame_id`
def read_frame_search_fire_csv(csv_file):
    with open(csv_file, 'r', encoding='utf-8-sig') as f:
        data = csv.DictReader(f)
        for line in data:
            yield line['video_id'], line['sentence']
            
multi_4_frame_search_fire_pipeline = (
    pipe.input('csv_file')
    .flat_map('csv_file', ('rel_frame_id', 'query'), read_frame_search_fire_csv)
    .map('query', 'vec', ops.image_text_embedding.clip(model_name='clip_vit_base_patch16', modality='text', device='mps'))
    .map('vec', 'vec', lambda x: x / np.linalg.norm(x))
    .map('vec', 'top10_raw_res', ops.ann_search.milvus_client(collection_name=FRAME_4_RET_COLLECTION, limit=15))
    .map('top10_raw_res', ('top1', 'top5', 'top10', 'top15'), lambda x: (x[:1], x[:5], x[:10], x[:15]))
    .output('rel_frame_id', 'query', 'top1', 'top5', 'top10', 'top15')
)

multi_8_frame_search_fire_pipeline = (
    pipe.input('csv_file')
    .flat_map('csv_file', ('rel_frame_id', 'query'), read_frame_search_fire_csv)
    .map('query', 'vec', ops.image_text_embedding.clip(model_name='clip_vit_base_patch16', modality='text', device='mps'))
    .map('vec', 'vec', lambda x: x / np.linalg.norm(x))
    .map('vec', 'top10_raw_res', ops.ann_search.milvus_client(collection_name=FRAME_8_RET_COLLECTION, limit=15))
    .map('top10_raw_res', ('top1', 'top5', 'top10', 'top15'), lambda x: (x[:1], x[:5], x[:10], x[:15]))
    .output('rel_frame_id', 'query', 'top1', 'top5', 'top10', 'top15')
)
            
fire_query_results_4 = DataCollection(multi_4_frame_search_fire_pipeline(FIRE_BENCHMARK_Q_JUDGEMENTS))
fire_query_results_8 = DataCollection(multi_8_frame_search_fire_pipeline(FIRE_BENCHMARK_Q_JUDGEMENTS))
# Out:
# 2025-04-17 14:58:14,505 - 8454604864 - clip.py-clip:100 - WARNING: Gpu not available, use cpu
# 2025-04-17 14:58:15,028 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:58:15,070 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:58:15,115 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/model.safetensors HTTP/1.1" 404 0
# 2025-04-17 14:58:15,120 - 16535318528 - connectionpool.py-connectionpool:1049 - DEBUG: Starting new HTTPS connection (1): huggingface.co:443
# 2025-04-17 14:58:15,184 - 16535318528 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16 HTTP/1.1" 200 3499
# 2025-04-17 14:58:15,638 - 16535318528 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/main HTTP/1.1" 200 3099
# 2025-04-17 14:58:15,732 - 16535318528 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/discussions?p=0 HTTP/1.1" 200 6380
# 2025-04-17 14:58:15,783 - 16535318528 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "GET /api/models/openai/clip-vit-base-patch16/commits/refs%2Fpr%2F10 HTTP/1.1" 200 4064
# 2025-04-17 14:58:15,784 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:58:15,862 - 16535318528 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors.index.json HTTP/1.1" 404 0
# 2025-04-17 14:58:15,894 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 2025-04-17 14:58:15,896 - 16535318528 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/refs%2Fpr%2F10/model.safetensors HTTP/1.1" 302 0
# 2025-04-17 14:58:15,948 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:58:16,139 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/processor_config.json HTTP/1.1" 404 0
# 2025-04-17 14:58:16,247 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.json HTTP/1.1" 404 0
# 2025-04-17 14:58:16,417 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.jinja HTTP/1.1" 404 0
# 2025-04-17 14:58:16,583 - 8454604864 - clip.py-clip:100 - WARNING: Gpu not available, use cpu
# 2025-04-17 14:58:16,610 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:58:16,642 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/config.json HTTP/1.1" 200 0
# 2025-04-17 14:58:16,686 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/model.safetensors HTTP/1.1" 404 0
# 2025-04-17 14:58:16,859 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:58:16,955 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 2025-04-17 14:58:16,992 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# 2025-04-17 14:58:17,108 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/processor_config.json HTTP/1.1" 404 0
# 2025-04-17 14:58:17,151 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.json HTTP/1.1" 404 0
# 2025-04-17 14:58:17,184 - 8454604864 - connectionpool.py-connectionpool:544 - DEBUG: https://huggingface.co:443 "HEAD /openai/clip-vit-base-patch16/resolve/main/chat_template.jinja HTTP/1.1" 404 0
# 2025-04-17 14:58:17,320 - 15227990016 - node.py-node:167 - INFO: Begin to run Node-read_frame_search_fire_csv-0
# 2025-04-17 14:58:17,320 - 15211163648 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-1
# 2025-04-17 14:58:17,321 - 15076552704 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2025-04-17 14:58:17,322 - 15442702336 - node.py-node:167 - INFO: Begin to run Node-ann-search/milvus-client-3
# 2025-04-17 14:58:17,323 - 15177510912 - node.py-node:167 - INFO: Begin to run Node-lambda-4
# 2025-04-17 14:58:17,326 - 16434360320 - node.py-node:167 - INFO: Begin to run Node-_output
# 2025-04-17 14:58:27,564 - 15194337280 - node.py-node:167 - INFO: Begin to run Node-_input
# 2025-04-17 14:58:27,571 - 16468013056 - node.py-node:167 - INFO: Begin to run Node-read_frame_search_fire_csv-0
# 2025-04-17 14:58:27,576 - 16451186688 - node.py-node:167 - INFO: Begin to run Node-image-text-embedding/clip-1
# 2025-04-17 14:58:27,578 - 16501665792 - node.py-node:167 - INFO: Begin to run Node-lambda-2
# 2025-04-17 14:58:27,578 - 15194337280 - node.py-node:167 - INFO: Begin to run Node-ann-search/milvus-client-3
# 2025-04-17 14:58:27,580 - 16518492160 - node.py-node:167 - INFO: Begin to run Node-lambda-4
# 2025-04-17 14:58:27,581 - 16535318528 - node.py-node:167 - INFO: Begin to run Node-_output

# %%
# Save FIRE queries
fire_query_results_4_df = twohee_data_col_to_df(fire_query_results_4)
fire_query_results_4_df.to_csv('query_results/multi_4_frame_queries_fire.csv', index=False)
fire_query_results_8_df = twohee_data_col_to_df(fire_query_results_8)
fire_query_results_8_df.to_csv('query_results/multi_8_frame_queries_fire.csv', index=False)

# %%
multi_4_fire_scores = get_all_eval_scores(fire_query_results_4_df)
multi_8_fire_scores = get_all_eval_scores(fire_query_results_8_df)
print("FIRE Metrics for 4 frame results")
pprint(multi_4_fire_scores)
print("FIRE Metrics for 8 frame results")
pprint(multi_8_fire_scores)
# Out:
# FIRE Metrics for 4 frame results
# {'map': 0.5466370943281771,
#  'ndcg@1': 0.445859872611465,
#  'ndcg@10': 0.5940961890411308,
#  'ndcg@5': 0.5800861023425389,
#  'recall@1': 0.445859872611465,
#  'recall@10': 0.7420382165605095,
#  'recall@5': 0.697452229299363}
# FIRE Metrics for 8 frame results
# {'map': 0.5742796481649985,
#  'ndcg@1': 0.49044585987261147,
#  'ndcg@10': 0.616343918349418,
#  'ndcg@5': 0.5961737289559949,
#  'recall@1': 0.49044585987261147,
#  'recall@10': 0.7484076433121019,
#  'recall@5': 0.6878980891719745}

# %% [markdown]
# ## Final scores for multi-frame-based video retrieval

# %%
scores_df = pd.DataFrame([get_all_eval_scores(multi_4_frame_msr_results_df), 
                          get_all_eval_scores(multi_8_frame_msr_results_df),
                          get_all_eval_scores(fire_query_results_4_df),
                          get_all_eval_scores(fire_query_results_8_df)
                          ], 
                         index=['4-Frames - MSRVTT Annotations', '8-Frames - MSRVTT Annotations',
                                '4-Frames - FIRE Queries', '8-Frames - FIRE Queries'])

styled_scores = scores_df.style.set_caption("Multi-Frame-based Retrieval Comparison").format("{:.3f}")

styled_scores
# Out:
# <style type="text/css">
# </style>
# <table id="T_cfed4">
#   <caption>Multi-Frame-based Retrieval Comparison</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfed4_level0_col0" class="col_heading level0 col0" >recall@1</th>
#       <th id="T_cfed4_level0_col1" class="col_heading level0 col1" >recall@5</th>
#       <th id="T_cfed4_level0_col2" class="col_heading level0 col2" >recall@10</th>
#       <th id="T_cfed4_level0_col3" class="col_heading level0 col3" >map</th>
#       <th id="T_cfed4_level0_col4" class="col_heading level0 col4" >ndcg@1</th>
#       <th id="T_cfed4_level0_col5" class="col_heading level0 col5" >ndcg@5</th>
#       <th id="T_cfed4_level0_col6" class="col_heading level0 col6" >ndcg@10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfed4_level0_row0" class="row_heading level0 row0" >4-Frames - MSRVTT Annotations</th>
#       <td id="T_cfed4_row0_col0" class="data row0 col0" >0.311</td>
#       <td id="T_cfed4_row0_col1" class="data row0 col1" >0.537</td>
#       <td id="T_cfed4_row0_col2" class="data row0 col2" >0.651</td>
#       <td id="T_cfed4_row0_col3" class="data row0 col3" >0.412</td>
#       <td id="T_cfed4_row0_col4" class="data row0 col4" >0.311</td>
#       <td id="T_cfed4_row0_col5" class="data row0 col5" >0.431</td>
#       <td id="T_cfed4_row0_col6" class="data row0 col6" >0.469</td>
#     </tr>
#     <tr>
#       <th id="T_cfed4_level0_row1" class="row_heading level0 row1" >8-Frames - MSRVTT Annotations</th>
#       <td id="T_cfed4_row1_col0" class="data row1 col0" >0.332</td>
#       <td id="T_cfed4_row1_col1" class="data row1 col1" >0.551</td>
#       <td id="T_cfed4_row1_col2" class="data row1 col2" >0.656</td>
#       <td id="T_cfed4_row1_col3" class="data row1 col3" >0.428</td>
#       <td id="T_cfed4_row1_col4" class="data row1 col4" >0.332</td>
#       <td id="T_cfed4_row1_col5" class="data row1 col5" >0.448</td>
#       <td id="T_cfed4_row1_col6" class="data row1 col6" >0.482</td>
#     </tr>
#     <tr>
#       <th id="T_cfed4_level0_row2" class="row_heading level0 row2" >4-Frames - FIRE Queries</th>
#       <td id="T_cfed4_row2_col0" class="data row2 col0" >0.446</td>
#       <td id="T_cfed4_row2_col1" class="data row2 col1" >0.697</td>
#       <td id="T_cfed4_row2_col2" class="data row2 col2" >0.742</td>
#       <td id="T_cfed4_row2_col3" class="data row2 col3" >0.547</td>
#       <td id="T_cfed4_row2_col4" class="data row2 col4" >0.446</td>
#       <td id="T_cfed4_row2_col5" class="data row2 col5" >0.580</td>
#       <td id="T_cfed4_row2_col6" class="data row2 col6" >0.594</td>
#     </tr>
#     <tr>
#       <th id="T_cfed4_level0_row3" class="row_heading level0 row3" >8-Frames - FIRE Queries</th>
#       <td id="T_cfed4_row3_col0" class="data row3 col0" >0.490</td>
#       <td id="T_cfed4_row3_col1" class="data row3 col1" >0.688</td>
#       <td id="T_cfed4_row3_col2" class="data row3 col2" >0.748</td>
#       <td id="T_cfed4_row3_col3" class="data row3 col3" >0.574</td>
#       <td id="T_cfed4_row3_col4" class="data row3 col4" >0.490</td>
#       <td id="T_cfed4_row3_col5" class="data row3 col5" >0.596</td>
#       <td id="T_cfed4_row3_col6" class="data row3 col6" >0.616</td>
#     </tr>
#   </tbody>
# </table>
